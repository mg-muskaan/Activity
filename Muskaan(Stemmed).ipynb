beef arrived it was soon revealed that we had held our appetite in unwarranted esteem at the end of that meal goutillon server stern no nonsense woman took an eyebrow cocked look at our barely empty dishes and shook her head in disapproval local hotel manager later reminded us of our misplaced bravado oh yeah heard about the indians who did not finish their steak he giggled france india in this time food special though india showing is strong bombay canteen chef thomas zacharias flagbearer for all things desi picks his top must haves from across the country devout traveller he dishes on where you can seek out the finest haleem and unforgettable curries we explore subcultures in delhi kolkata and mumbai through three different food walks writer reema islam pens heartfelt ode to dolmades the grecian staple that is intertwined with her own history of growing up in libya and bangladesh antoine lewis gathers list of kitchen maestros from alex atala to reclusive monk in south korea each of whom are worth pilgrimage ardent gourmands might also want to consider dubrovnik which in writer david farley words is europe emerging food capital as you can tell by the examples above we were guided by pure gluttony this time ']'''

# %%
#Tokenization(Sridhar)
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

tokens = word.split(' ')
sentences = word.split('.')
stop =["is","and","the","a","this","have","to","anyhow","has","for","This","my","My","Mine","here","There","So"]
print("tokens")
print(tokens)
print("Sentences")
print(sentences)

#Finding Number of Stop words
print("Number of tokens ")
print(len(tokens))
count = 0
for i in tokens:
  if i == '':
    count = count + 1
print("Number of Space ")
print(count)
count = 0
for i in tokens:
 if i in stop:
  count = count + 1
print("Number of stop words ")
print(count)

#removing stop words
main = []
for i in tokens:
 if i not in stop and i != '':
  main.append(i)
print("Stop words are removed")
print(main)
# Out:
# tokens
# ...

# %%
#Stemming(Muskaan Gupta 17BCE0167)
import nltk
from nltk.stem import SnowballStemmer
stemmed=[]
stemmerSnow= SnowballStemmer(language='english')
for w in main:
    stemmed.append(stemmerSnow.stem(w))
print(stemmed)
# Out:
# ["['our", 'year', 'end', 'edit', 'toast', 'ultra', 'indulg', 'while', 'travel', 'featur', 'itinerari', 'that', 'mani', 'will', 'know', 'be', 'out', 'of', 'their', 'financi', 'reach', 'in', 'produc', 'these', 'narrat', 'was', 'struck', 'by', 'contrast', 'travel', 'today', 'domin', 'by', 'minimalist', 'or', 'downsize', 'those', 'who', 'preach', 'gospel', 'of', 'hard', 'knock', 'wanderlust', 'they', 'almost', 'alway', 'reap', 'univers', 'admir', 'they', 'are', 'charact', 'aspir', 'exampl', 'of', 'made', 'instagram', 'say', 'such', 'as', 'all', 'you', 'need', 'backpack', 'or', 'motorcyclediari', 'unabl', 'join', 'these', 'galliv', 'philosoph', 'other', 'marvel', 'at', 'their', 'brave', 'rebellion', 'oh', 'give', 'up', 'predict', 'of', 'overpr', 'tourist', 'trap', 'someday', 'they', 'sigh', 'in', 'context', 'luxuri', 'travel', 'evok', 'molotov', 'cocktail', 'of', 'feel', 'billionair', 'on', 'sailboat', 'host', 'jazz', 'age', 'style', 'revelri', 'in', 'french', 'riviera', 'inevit', 'set', 
# ...
